# %%
import os
os.environ['GOOGLE_API_KEY'] = "AIzaSyCKHaFNrvl_AKxEvM7uHewW8dSpv4MfaMk"

# %%
import os
import google.generativeai as genai
from PIL import Image

# Set your API key
os.environ['GOOGLE_API_KEY'] = "AIzaSyCKHaFNrvl_AKxEvM7uHewW8dSpv4MfaMk"

genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

def send_text_request(prompt):
    model = genai.GenerativeModel('gemini-pro')
    response = model.generate_content(prompt)
    return response.text

def image_analysis_request(image_path):
    model = genai.GenerativeModel('gemini-pro-vision')
    image = Image.open(image_path)
    response = model.generate_content(["Analyze the image", image])
    return response.text

if __name__ == '__main__':
    while True:
        user_input = input("You: ")
        if ' show image' in user_input.lower():
            image_path = input("Enter the path of the image file: ")
            output = image_analysis_request(image_path)
            print("Assistant:", output)
        else:
            output = send_text_request(user_input)
            print("Assistant:", output)
# Out:
# Assistant: ```
#                                        .-"""-.
#                     .-""""""""""-.    /      \
#                 .-'             `\  /        \
#              .-'                 ||          \
#             /                      ||    _.-"""-.
#            ;                       ||   /        \
#           /:.                     ||  ;          \
#          / /                      ||  /;          ;\
#         ; ;         __             ||  ||        _||
#         | ;        ," \/`.          ||  ||       /   \
#         | |        /    /  \         ||  ||       \   /
#         ; ;        `.  !   | `.       ||  ;        Y /
#         | ;       ,'  /    ;  \      ||  |         | |
#          \ \     /   ,'    ;   \     |\  \         / /
#        .-'  L__.'    ;     |    ;    /  \  \       /  '.'-._
#       / ,..  ,--,         |    |   /    `\ `\    (    /   \
#      / ; |   .-. `.      (    |  /        \ \ \   `.     \
#      \ ; |   \ \_/`.    |    | /          )  )   |      \
#      | ; |    \     `\  )   _\'          /  /    |       \
#       \ \._,--'\  `-.`' \   \  `"""""`"""""/   .'    __    |
#       `.             `.  \   \_          /   /    .-'   `.
#         `.    '._    .' \   `..`..'  _..'  _/     /        \
#           `-..-' /`. |   \    \   /  /    .'     /          \
#                  |  `.`.  '._  \ /  .'     /     ;           \
#                  \   `.`.    \ \ | /     /    /.'            \
#                  \   / `-.`\  'Y.'    .'  _.-'              ;
#                   \  ;     .-."  `\   / .'                /
#                    \ \    /  /      `-'                  /
#                     `.`.  /  /                          /
#                      /  `-'                          /
#                    .-'    _.'                         /
#                  .'    .-' `\                       /
#                 /   .-'`.    `.                     /
#                /   /     `.    `\                 /
#               ;   ;       `.`._ `\              |
#              /    |         `.  .`\           .'
#             /     |           `.  `-.      .-'
#            /      |             `._  `\.-'
#           /   .. ;                   ``
#           \   ''/                        |
#           /    /                         ;
#          ;    /        .-"""""-.         |
#         ;    ;      .'         `.       :
#         \    ;    /          _  \`.     ;
#          \   ;   ;         / \   `.   :
#           `.  ;  /        /   `.   '._.'
#             `-;  ;  `"""""`'    `-.  '-.
#             .-' /.'             \   \   `.
#         .-'    ; ;               ``. `._  `.
#         /      ; ;                `._`-. `-._\
#         ;      ; ;                  `-._`-._  \
#         \    .' |                   _.-'  .' .'
#          `.  ;  ;                  |   .'  ; ;
#            `. |  ;                 /   ;  /  ;
#            _`.|  ;                ; `-  /  /
#          .'   `. /              .'   .'   .'
#         /      .`-._     _.-'    .'    ;   \
#        ;        `.  `-.`         ;     /_.-;
#       /         .' .' _          ;    .' .' /
#      /         /.  .'  '-.       / .'  .'  ;
#     ;      .-''  .'     '.    .' ,' .'  .'  ;
#     |     /      ;        `-. /  /    ;   ;
#     ;    /       |.-"""""-.   .'     ;   /
#     |    .'      /   .'  '.  ;      /   ;
#     ;   |       .'    ;   '. `.    .'   /
#      \  /      .'     '.    \  \   '.'   ;
#       `'     .'       '.    ` `\  '.    /
#             `.         `.    `. `\  `.  /
#               `-.        `._    `._`-.'  ;
#                 `.    .-''||`'--'   /     /
#                   `..'     ``       .'     /
#                      `-..        _.'       |
#                          `-. /.''         '
#                             `-'           '
# Assistant: ```
#    .-"""-.
#   /       \
#  ;         ;
#  |         |
#  |         ;.-.
#  ;-.____.-'/   \
# /          |     \
# \          /       '._
#  `'-------'         `.
#                       \|
#                        \ \
#     .-"""-.-.-.-.-.-.-.-.-.-'`_.-.-.-.
#  _/  /    |               /    \  \.-._
#  |  /     ;               |     |  \   \
#  | /      |               |      |   )   `
#  |/       |               |       |  /
#   \       |               |       | /
#    `.     |               |     .'.'
#      `\   |               |   /'.'
#         ) |               |  /.'
#        /  |               | /'
#       /   |               |/
#      /    ;              .'
#     /     |            .'
#    |      \          .'
#    |       ).      .'
#    |       / )----(
#    |      / /     )
#    |     / /    .'
#    )    / /   .'
#   (    / / .'
#   )   / /
#  (_.'.'
# Assistant: <start_of_image> in the lake
# Assistant: [Image of a horse](https://upload.wikimedia.org/wikipedia/commons/thumb/d/d6/Quarter_Horse_running.jpg/1200px-Quarter_Horse_running.jpg)
# Assistant: * https://upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Holsteiner_horse.jpg/1200px-Holsteiner_horse.jpg
# * https://www.rd.com/wp-content/uploads/2020/11/GettyImages-607244312.jpg
# * https://images.unsplash.com/photo-1519345846001-d3afc17f6c31?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=1280&q=80
# * https://upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Equus_ferus_caballus_-_adult_stallion.jpg/1200px-Equus_ferus_caballus_-_adult_stallion.jpg
# * https://cdn.britannica.com/s:800x450,c:crop/41/15541-050-4C0BD16E/horse-animal-species.jpg
# Assistant: [Image of a horse](https://upload.wikimedia.org/wikipedia/commons/thumb/d/d0/Przewalski%27s_Horse_Equus_ferus_przewalskii%2C_Tierpark_Berlin%2C_Germany_-_Diliff.jpg/1200px-Przewalski%27s_Horse_Equus_ferus_przewalskii%2C_Tierpark_Berlin%2C_Germany_-_Diliff.jpg)
# Assistant: [Image of a horse running in a field](https://upload.wikimedia.org/wikipedia/commons/thumb/e/e2/Equus_ferus_caballus_-_running_horse.jpg/1280px-Equus_ferus_caballus_-_running_horse.jpg)
#
# [Image of a horse standing in a stable](https://upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Gray_horse_in_stable.jpg/1280px-Gray_horse_in_stable.jpg)
#
# [Image of a horse grazing in a meadow](https://upload.wikimedia.org/wikipedia/commons/thumb/8/88/Young_horse_grazing_meadow.jpg/1280px-Young_horse_grazing_meadow.jpg)
# Assistant: [Image of an AI-generated horse]
# Assistant: **Image Sources:**
#
# * **Unsplash:** https://unsplash.com/
# * **Pexels:** https://www.pexels.com/
# * **Burst:** https://burst.shopify.com/
# * **StockSnap:** https://stocksnap.io/
# * **Pixabay:** https://pixabay.com/
# * **RawPixel:** https://www.rawpixel.com/
# * **iStock:** https://www.istockphoto.com/
# * **Getty Images:** https://www.gettyimages.com/
# * **Shutterstock:** https://www.shutterstock.com/
# * **Freepik:** https://www.freepik.com/
# * **Vecteezy:** https://www.vecteezy.com/
#
# **Video Sources:**
#
# * **YouTube:** https://www.youtube.com/
# * **Vimeo:** https://vimeo.com/
# * **Dailymotion:** https://www.dailymotion.com/
# * **Metacafe:** https://www.metacafe.com/
# * **Vidyard:** https://www.vidyard.com/
# * **Twitch:** https://www.twitch.tv/
# * **Rumble:** https://rumble.com/
# * **Odysee:** https://odysee.com/
#
# **Music Sources:**
#
# * **Audionautix:** https://audionautix.com/
# * **Free Music Archive:** https://freemusicarchive.org/
# * **Incompetech:** https://incompetech.filmmusic.io/
# * **MusOpen:** https://musopen.org/
# * **BenSound:** https://www.bensound.com/
# * **SoundCloud:** https://soundcloud.com/
# * **Epidemic Sound:** https://www.epidemicsound.com/
# * **AudioJungle:** https://audiojungle.net/
# * **PremiumBeat:** https://www.premiumbeat.com/
#
# **Document Sources:**
#
# * **Google Docs:** https://docs.google.com/
# * **Microsoft Word:** https://www.microsoft.com/en-us/microsoft-365/word
# * **Apple Pages:** https://www.apple.com/pages/
# * **LibreOffice Writer:** https://www.libreoffice.org/discover/writer/
# * **Scrivener:** https://www.literatureandlatte.com/scrivener/
# * **Wattpad:** https://www.wattpad.com/
#
# **Code and Software Sources:**
#
# * **GitHub:** https://github.com/
# * **Bitbucket:** https://bitbucket.org/
# * **GitLab:** https://gitlab.com/
# * **SourceForge:** https://sourceforge.net/
# * **NPM:** https://www.npmjs.com/
# * **PyPI:** https://pypi.org/
# * **Stack Overflow:** https://stackoverflow.com/
# Assistant: <start_of_image>Percheron draft horse: https://upload.wikimedia.org/wikipedia/commons/a/a8/Percheron_2018.jpg
# Friesian horse: https://upload.wikimedia.org/wikipedia/commons/e/e4/Friesian_Horse_2019.jpg
# American Quarter Horse: https://upload.wikimedia.org/wikipedia/commons/4/46/American_Quarter_Horse_2018.jpg
# Appaloosa horse: https://upload.wikimedia.org/wikipedia/commons/f/f1/Appaloosa_2018.jpg
# Arabian horse: https://upload.wikimedia.org/wikipedia/commons/4/49/Arabian_horse_on_white_background.jpg
# Clydesdale horse: https://upload.wikimedia.org/wikipedia/commons/6/6a/Clydesdale_2018.jpg
# Haflinger horse: https://upload.wikimedia.org/wikipedia/commons/d/dc/Haflinger_2018.jpg
# Morgan horse: https://upload.wikimedia.org/wikipedia/commons/8/84/Morgan_horse_head_shot.jpg
# Mustang horse: https://upload.wikimedia.org/wikipedia/commons/2/28/Mustang_2018.jpg
# Paint horse: https://upload.wikimedia.org/wikipedia/commons/4/47/Paint_Horse_2018.jpg
# Palomino horse: https://upload.wikimedia.org/wikipedia/commons/9/9f/Palomino_2018.jpg
# Quarter horse: https://upload.wikimedia.org/wikipedia/commons/3/3e/Quarter_Horse_2018.jpg
# Shire horse: https://upload.wikimedia.org/wikipedia/commons/a/a5/Shire_2018.jpg
# Standardbred horse: https://upload.wikimedia.org/wikipedia/commons/b/b3/Standardbred_2018.jpg
# Thoroughbred horse: https://upload.wikimedia.org/wikipedia/commons/7/7b/Thoroughbred_2018.jpg
# Warmblood horse: https://upload.wikimedia.org/wikipedia/commons/f/f8/Warmblood_2018.jpg
# Assistant: <start_of_image>UNSPLASH
# https://unsplash.com/photos/M1E7buvmxvs
#
# PEXELS
# https://www.pexels.com/search/horse/
#
# FLICKR
# https://www.flickr.com/search/?text=horse&view_all=1
#
# PICSEARCH
# https://picsearch.com/search/horse?search_source=web&fchk=1
#
# GOOGLE IMAGES
# https://www.google.com/search?q=horse&tbm=isch&ved=2ahUKEwi21YiUn5v6AhXXQ0EAHZtTC7EQ2-cCegQIABAA&oq=horse&gs_lcp=CgNpbWcQAzIECAAQQzIECAAQQzIECAAQQzIECAAQQzIECAAQQzICCAAyAgQIABAMOgYIABAWEB4eBAgQClAWOgcIABCxAxBDUP0PWIreFmgAcAB4AIABdIgBe5IBAzAuMZgBAKABAaoBC2d3cy13aXotaW1n&sclient=img&ei=l49KYv_aL4zbggeRuIxg
#
# ADOBE STOCK
# https://stock.adobe.com/search?k=horse
#
# SHUTTERSTOCK
# https://www.shutterstock.com/search/horse
#
# GETTY IMAGES
# https://www.gettyimages.com/photos/horse
#
# ISTOCKPHOTO
# https://www.istockphoto.com/search/horse
