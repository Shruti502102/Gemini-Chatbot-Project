# %%
pip install nltk

# %%
import nltk
nltk.download("punkt")  # For tokenization
nltk.download("stopwords")  # For stopword removal
nltk.download("wordnet")  # For lemmatization
import nltk
nltk.download("punkt")  # For tokenization
nltk.download("stopwords")  # For stopword removal
nltk.download("wordnet")  # For lemmatization
# Download the 'punkt_tab' resource
nltk.download('punkt_tab')
nltk.download("wordnet")  # For lemmatization
# Download the 'punkt_tab' resource
nltk.download('punkt_tab')

# %%
import nltk
nltk.download("punkt")  # For tokenization
nltk.download("stopwords")  # For stopword removal
nltk.download("wordnet")  # For lemmatization

# %%
import nltk
import string
import warnings
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Download required NLTK data
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")

warnings.filterwarnings("ignore")

# Predefined 100+ question-answer pairs
responses = {
    "hello": "Hi there! How can I assist you?",
    "hi": "Hello! What can I do for you?",
    "how are you": "I'm just a chatbot, but I'm doing great! What about you?",
    "bye": "Goodbye! Have a great day!",
    "your name": "I'm a simple chatbot powered by NLP!",
    "who created you": "I was created by a developer using Python and NLP techniques.",
    "what is AI": "AI stands for Artificial Intelligence, which enables machines to learn and make decisions.",
    "what is machine learning": "Machine Learning is a subset of AI that allows machines to learn from data.",
    "what is deep learning": "Deep Learning is a type of ML that uses neural networks to process data.",
    "what is NLP": "Natural Language Processing (NLP) helps computers understand and process human language.",
    "what is big data": "Big Data refers to large and complex datasets that require special tools for processing.",
    "what is Python": "Python is a versatile programming language used in AI, web development, and more.",
    "what is TensorFlow": "TensorFlow is an open-source library for machine learning and deep learning applications.",
    "what is ReactJS": "ReactJS is a JavaScript library for building interactive user interfaces.",
    "what is Data Science": "Data Science involves extracting insights from structured and unstructured data.",
    "what is cloud computing": "Cloud computing provides on-demand access to computing resources via the internet.",
    "what is an API": "An API (Application Programming Interface) allows different software systems to communicate.",
    "what is GitHub": "GitHub is a platform for version control and collaborative software development.",
    "what is blockchain": "Blockchain is a decentralized digital ledger used for secure transactions.",
    "what is cybersecurity": "Cybersecurity protects systems and networks from cyber threats and attacks.",
    "what is IoT": "IoT (Internet of Things) refers to connected devices that communicate over the internet.",
    "what is SQL": "SQL (Structured Query Language) is used to manage and query databases.",
    "what is NoSQL": "NoSQL databases store unstructured data and are suitable for big data applications.",
    "what is computer vision": "Computer Vision enables computers to interpret and process visual information.",
    "what is a chatbot": "A chatbot is an AI-driven program that interacts with users via text or voice.",
    "what is 5G": "5G is the fifth generation of mobile networks, offering faster internet speeds.",
    "what is metaverse": "The Metaverse is a virtual world where people interact using digital avatars.",
    "what is augmented reality": "Augmented Reality (AR) enhances real-world environments with digital overlays.",
    "what is virtual reality": "Virtual Reality (VR) creates a fully immersive digital environment.",
    "what is quantum computing": "Quantum computing uses quantum bits (qubits) for advanced computations.",
    "what is edge computing": "Edge computing processes data closer to the source, reducing latency.",
    "what is an algorithm": "An algorithm is a step-by-step procedure for solving a problem.",
    "what is hashing": "Hashing converts data into a fixed-size value for security purposes.",
    "what is encryption": "Encryption secures data by converting it into an unreadable format.",
    "what is data mining": "Data mining extracts useful patterns and knowledge from large datasets.",
    "what is reinforcement learning": "Reinforcement learning is a type of ML where agents learn by trial and error.",
    "what is supervised learning": "Supervised learning trains models using labeled data.",
    "what is unsupervised learning": "Unsupervised learning finds patterns in data without labels.",
    "what is neural network": "A neural network mimics the human brain to process complex data.",
    "what is sentiment analysis": "Sentiment analysis detects emotions in text using NLP techniques.",
    "what is feature engineering": "Feature engineering selects and transforms variables to improve ML models.",
    "what is data preprocessing": "Data preprocessing cleans and prepares data for analysis or ML models.",
    "what is overfitting": "Overfitting occurs when an ML model learns noise instead of patterns.",
    "what is underfitting": "Underfitting happens when a model fails to learn patterns from data.",
    "what is bias in AI": "Bias in AI occurs when models favor certain outcomes due to biased data.",
    "what is cloud storage": "Cloud storage allows users to store and access data online.",
    "what is HTTP": "HTTP (HyperText Transfer Protocol) enables web communication.",
    "what is HTTPS": "HTTPS is a secure version of HTTP that encrypts data during transfer.",
    "default": "I'm still learning. Can you rephrase that?"
}

# Text preprocessing function
def preprocess_text(text):
    text = text.lower()  # Convert to lowercase
    text = text.translate(str.maketrans("", "", string.punctuation))  # Remove punctuation
    words = word_tokenize(text)  # Tokenize text
    words = [w for w in words if w not in stopwords.words("english")]  # Remove stopwords
    return " ".join(words)

# Lemmatization function
def lemmatize_text(text):
    lemmatizer = WordNetLemmatizer()
    words = text.split()
    return " ".join([lemmatizer.lemmatize(word) for word in words])

# Chatbot response function
def get_response(user_input):
    processed_input = preprocess_text(user_input)
    processed_input = lemmatize_text(processed_input)  # Apply lemmatization

    # Partial matching: Check if any key exists in the processed input
    for key in responses:
        if key in processed_input:
            return responses[key]

    return responses["default"]

# Interactive chatbot loop
print("Chatbot: Hello! Type 'exit' to stop.")
while True:
    user_input = input("You: ")
    if user_input.lower() == "exit":
        print("Chatbot: Goodbye!")
        break
    response = get_response(user_input)
    print("Chatbot:", response)

# %%
import nltk
import random
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Download required NLTK data
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")

# Sample chatbot responses
responses = {
    "hello": "Hi there! How can I assist you?",
    "hi": "Hello! What can I do for you?",
    "how are you": "I'm just a chatbot, but I'm doing great! What about you?",
    "bye": "Goodbye! Have a great day!",
    "what is AI": "AI stands for Artificial Intelligence, which enables machines to learn and make decisions.",
    "what is machine learning": "Machine Learning is a subset of AI that allows machines to learn from data.",
    "what is python": "Python is a powerful programming language used in AI, web development, and more.",
    "what is SQL": "SQL (Structured Query Language) is used to manage and query databases.",
    "what is NoSQL": "NoSQL databases store unstructured data and are used for big data applications.",
    "what is cloud computing": "Cloud computing provides on-demand computing services over the internet.",
    "default": "I'm still learning. Can you rephrase that?"
}

# Text preprocessing function
def preprocess_text(text):
    text = text.lower()  # Convert to lowercase
    text = text.translate(str.maketrans("", "", string.punctuation))  # Remove punctuation
    words = word_tokenize(text)  # Tokenize text
    words = [w for w in words if w not in stopwords.words("english")]  # Remove stopwords
    return " ".join(words)

# Chatbot response function
def get_response(user_input):
    processed_input = preprocess_text(user_input)

    # Check if any response key is in the processed input
    for key in responses:
        if key in processed_input:
            return responses[key]

    return responses["default"]

# Interactive chatbot loop
print("Chatbot: Hello! Type 'exit' to stop.")
while True:
    user_input = input("You: ")
    if user_input.lower() == "exit":
        print("Chatbot: Goodbye!")
import nltk
import random
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Download required NLTK data
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")

# Sample chatbot responses
responses = {
    "hello": "Hi there! How can I assist you?",
    "hi": "Hello! What can I do for you?",
    "how are you": "I'm just a chatbot, but I'm doing great! What about you?",
    "bye": "Goodbye! Have a great day!",
    "what is AI": "AI stands for Artificial Intelligence, which enables machines to learn and make decisions.",
    "what is machine learning": "Machine Learning is a subset of AI that allows machines to learn from data.",
    "what is python": "Python is a powerful programming language used in AI, web development, and more.",
    "what is SQL": "SQL (Structured Query Language) is used to manage and query databases.",
    "what is NoSQL": "NoSQL databases store unstructured data and are used for big data applications.",
    "what is cloud computing": "Cloud computing provides on-demand computing services over the internet.",
    "default": "I'm still learning. Can you rephrase that?"
}

# Text preprocessing function
def preprocess_text(text):
    text = text.lower()  # Convert to lowercase
    text = text.translate(str.maketrans("", "", string.punctuation))  # Remove punctuation
    words = word_tokenize(text)  # Tokenize text
    words = [w for w in words if w not in stopwords.words("english")]  # Remove stopwords
    return " ".join(words)

# Chatbot response function
def get_response(user_input):
    processed_input = preprocess_text(user_input)

    # Check if any response key is in the processed input
    for key in responses:
        if key in processed_input:
            return responses[key]

    return responses["default"]

# Interactive chatbot loop
print("Chatbot: Hello! Type 'exit' to stop.")
while True:
    user_input = input("You: ")
    if user_input.lower() == "exit":
        print("Chatbot: Goodbye!")
        break
    response = get_response(user_input)
    print("Chatbot:", response)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Chatbot: Hello! Type 'exit' to stop.
